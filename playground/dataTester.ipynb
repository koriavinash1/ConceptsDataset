# %%
# %load_ext autoreload
# %autoreload 2

import sys 
import os
import numpy as np
import matplotlib.pyplot as plt

sys.path.append('..')

from src.utils import CreateObject, show_image

# %%
objectClass = CreateObject(128, 128)

# %%
types = ['square', 'triangle', 'pentagon']
concepts1 = [objectClass.sample(n=10, type=type_) for type_ in types]
show_image(concepts1, types, False)
show_image([objectClass.combine(concepts1)], ['combined'], False)
# Out:
# ../src/utils.py:245: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
types = ['circle', 'capsule', 'ellipse']
concepts2 = [objectClass.sample(n=10, type=type_) for type_ in types]
show_image(concepts2, types, False)
show_image([objectClass.combine(concepts2)], ['combined'], False)

# %%
types = ['square', 'circle', 'capsule', 'ellipse', 'triangle']
concepts3 = [objectClass.sample(n=10, type=type_) for type_ in types]
show_image(concepts3, types, False)
show_image([objectClass.combine(concepts3)], ['combined'], False)

# %%
show_image([objectClass.combine(concepts1)], ['combined'], False)
show_image([objectClass.combine(concepts2)], ['combined'], False)
show_image([objectClass.combine(concepts3)], ['combined'], False)

# %%
from src.main import CreateDataset

dbcreator = CreateDataset(N= 40000, 
                    batch_size=10,
                    height=128,
                    width=128,
                    Kconcepts=5, 
                    nclasses=3,
                    classes={1: ['circle', 'capsule', 'ellipse'],
                                2: ['square', 'pentagon', 'triangle']},
                    save_dir='../SimplestData/training')

dbcreator.create()

# %%
dbcreator = CreateDataset(N= 8000, 
                    batch_size=10,
                    height=128,
                    width=128,
                    Kconcepts=5, 
                    nclasses=3,
                    classes={1: ['circle', 'capsule', 'ellipse'],
                                2: ['square', 'pentagon', 'triangle']},
                    save_dir='../SimplestData/testing')

dbcreator.create()
