# %%
# %load_ext autoreload
# %autoreload 2

import sys 
import os
import numpy as np
import matplotlib.pyplot as plt

sys.path.append('..')

from src.utils import CreateObject, show_image
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
objectClass = CreateObject(128, 128)

# %%
types = ['square', 'circle', 'capsule', 'ellipse', 'triangle', 'hexagon', 'octagon', 'pentagon']
concepts = [objectClass.sample(n=10, type=type_) for type_ in types]
show_image(concepts, types, False)
# Out:
# ../src/utils.py:209: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
